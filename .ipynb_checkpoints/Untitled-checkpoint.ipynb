# %%
import string
from collections import Counter
import re
import pickle
with open('data/train.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
comments, codes = zip(*data)

# %%
comments
# Out:
# ('Embedding a networkx graph into wxPython with matplotlib',
#  'Extract information from multiple CSV files, write to new CSV with third column',
#  "how to 'marry' two strings in python?",
#  'Django - template context processors - breaking my app',
#  'making a python dictionary accessible inside a function',
#  'How to check if two words are ordered in python',
#  'broadcasting linalg.pinv on a 3D matrix',
#  'Is there any module that can handle unidentified variables?',
#  'How can I write a function that does nothing for a given length of time?',
#  "What's the idiomatic syntax for prepending to a short python list?",
#  'Extracting a specific part of a string with regular expression in Python',
#  'Python3.2 How to keep turtle from going off the screen and when it does reset?',
#  'NLTK stem words produces odd results',
#  'Pandas drop duplicates if reverse is present between two columns',
#  'WxPython StaticLine after Image in BoxSizer',
#  'Getting name of field that is primary_key',
#  'Plotting A Hyperboloid ',
#  'Insert data into specific table (sqlalchemy)',
#  'Avoiding quotes around row of string data with csv.writer',
#  'Saving a json file to computer python',
#  'How to use ManyToManyField with condition',
#  'Trying to grab just absolute links from a webpage using BeautifulSoup',
#  'Exit Tks mainloop in Python?',
#  'How to merge multiple returned lists into one',
#  'wx.ListCtrl with TextEditMixin - Disable Editing of Selected Cells',
#  'How can I create a tree using the python package ete2 using strings stored in a list?',
#  'Cython direct access to Global Variable',
#  'How to STDIN and STDOUT with PHP and Python to use html2text and get a markdown formated text?',
#  'How to iterate over a list repeating each element in Python',
#  'Using Matplotlib imshow to show GIF image',
#  'How to break the input from dictionary python',
#  'Append new data to a .csv?',
#  'Read a File from redirected stdin with python',
#  "How to get process's grandparent id",
#  'Django Exclude in list_filter with custom filter',
#  'How to test template context variables with Flask',
#  'How to resample a python pandas TimeSeries containing dytpe Decimal values?',
#  'create multiple objects using writable nested serializers in django rest framework 3',
#  'Getting specific data with BeautifulSoup',
#  'Coding words as products of integers',
#  "How to fit two arrays containing csr_matrixs' and labels respectively?",
#  'title and axis gets over each other',
#  'Replace a <div> tag to <h2> tag using BeautifulSoup',
#  'crawling twitter using urllib instead of twitter api',
#  'Changing the color of the axis, ticks and labels for a plot in matplotlib',
#  'numpy.argmax: how to get the index corresponding to the *last* occurrence, in case of multiple occurrences of the maximum values',
#  'Validate user input using regular expressions',
#  'Higher order python functions and setting their attributes correctly',
#  'Finding matching filenames between directories',
#  'Meassure website load time with python requests',
#  'Which is a more efficient __hash__ implementation in Python objects? Hashing self.__str__, a tuple of attributes, or a real hash routine?',
#  'Converting python files and PyQt into a windows executable?',
#  'Created file contains all the results python lxml',
#  'How can I use autoincrementing column value as default value for another not nullable column?',
#  'How to calculate Absolute value in z3 or z3py',
#  'From multidimensional array to hierarchy',
#  'how to run(copy) django project from one system from another system?',
#  'Python application multi-threading for dev environment only',
#  'Reading specific Column Values from CSV and pass it to urllib as parameter in Python',
#  'finding substring',
#  'Changing values in nested lists with python',
#  'How to clean images in Python / Django?',
#  'how to load a page parser?',
#  'Implement SMPP in Python',
#  'Modeling a linear system with Python',
#  'Converting string to tuple and adding to tuple',
#  'How to run a python program that uses numpy on multiple cores, preferably using threading',
#  'Package import creates a module, submodules still importable',
#  'Get percentage of a letter in python dictionary',
#  'How can python return the filename currently being processed under Windows',
#  "get a phone number's international prefix from a country code in python",
#  'ScrolledPanel with vertical scrollbar only and WrapSizer',
#  'Python: print base class variables',
#  'Two Tkinter Images',
#  'Replacing Pandas PivotTable Non-Null Result Cells With A Fixed String',
#  'Biopython PDB extract coordinate(x,y,z) and b value data if b value>10 && <50',
#  'How to merge a list of dict to one dict',
#  'Return to previously generated axis in matplotlib',
#  'How do I create a series of high- and low-pitch beeps using Ruby or Python?',
#  'Using the Pythons email.message API, how do you remove a specific part of the message',
#  'Efficiently create a density plot for high-density regions, points for sparse regions',
#  'Trouble calling EMBOSS program from python',
#  'Formatting sql %like%',
#  'Object level cascading permission in Django',
#  'Tracking file load progress in Python',
#  'Cannot access member variable using abc module and properties in python',
#  'How to convert HEX data into BINARY data?',
#  'Select a substring before the second occurrence of a character without a string slice',
#  'flask-sqlalchemy - PostgreSQL - Define specific schema for table?',
#  'How to implement a Quick Sort in Python',
#  'Find largest file inside of tarball',
#  'How to use bcrypt on Google App Engine (GAE)?',
#  'Deriving an SSH Fingerprint from a Public Key in Python',
#  'How do I list all classes of a given type in a python file?',
#  'Send AT-command through bluetooth from python application',
#  'Maximize the sum between two lists of integers? (with restrictions)',
#  "Python/Tikinter: Can't use a button to update a graph?",
#  'Python/Pygame: How to break a while loop initiated by KEYDOWN event with a KEYUP event?',
#  'Finding closest values in a list of dictionary keys Python',
#  'Match string segments in regular expressions',
#  'Suggestions on ways to store file information using python',
#  'How to make a function a bound method',
#  'Convert XML to CSV',
#  'Displaying OpenCV iplimage data structures with wxPython',
#  'python - how to convert html string to utf-8? Getting UnicodeDecodeError errors',
#  'How to transpose this dataframe?',
#  "How do I use the card fingerprint feature of Stripe's API via their Python library?",
#  'Python:how to change string or list elements',
#  'How do i sort my text file alphabeticaly yet keep the line spaces',
#  'Django Form Wizard - Setting default value for text input field',
#  'how to open a url in python',
#  'Parse data from html page to table',
#  'Python web interface for sensors',
#  'Turn float object into tuple',
#  'Getting python to respond to a specific key press',
#  'populate dictionary with for loop',
#  'xlwings - Get and set named ranges',
#  'Python dateutils print recurrence rule according to iCalendar format (see RFC 5545)',
#  'Python: writing integers to a single byte',
#  'How to expose a dbus method with multiple arguments?',
#  'Django model with editable=False and filter that field in Admin',
#  'How do I make a python window always be on bottom?',
#  'Using numbers in lists as characters',
#  'Merge items of two lists into list of tuples that also contains index',
#  'Dealing with zeros in numpy array normalization',
#  'Dictionary into dictionary in python',
#  "Selecting directory's path with tkinter",
#  'Django - retrieve form data',
#  'How can you print a key given a value in a dictionaty for Python?',
#  'Decoding error message from tracker',
#  'How to redraw text on gradient background in pygame?',
#  'Calculating daily average from irregular time series using pandas',
#  'Draw underline text with PIL',
#  'How to break a Python while loop from a function within the loop',
#  "How to use OR using Django's model filter system?",
#  'Best practice for polling an AWS SQS queue and deleting received messages from queue?',
#  'Starting a VirtualBox VM from a Python Script',
#  'Django: Naive datetime while time zone support is active (sqlite)',
#  'How to set ETAGS on Google App Engine for Python?',
#  'Filter related set in a related set',
#  'How does a polar plot work in pyplot?',
#  'how to adding new tab in readline python',
#  'Trying to print out data from database',
#  'Format a python list and search for patterns',
#  'Add new colormap from file (.h) - Python',
#  'How to write query for joining three tables with filter and order by condition in django',
#  'Python Help: How to find if 3 or 4 strings are the same in a list of 7 strings?',
#  'how to use variable in recursion in python',
#  'Enter adb shell from python',
#  'Python Play sound using pygame',
#  'Pass function of function as parameter',
#  'c++ map<int, int> in python',
#  'Displaying python 2d list without commas, brackets, etc. and newline after every row',
#  'How to find the relative path between two directories?',
#  'Using Rich Text Editor in Django admin with tinymice',
#  'How to tell the HTTP server to not send chunked encoding',
#  'How Enable Extended MQL When Reading From Freebase API',
#  'about python regular expression match from right direction',
#  'How do I extract some string from a long string in Python?',
#  'Picking dates from an imported CSV with pandas/python',
#  'ORM for google cloud datastore',
#  "How to truncate data in a dict so that the resulting JSON isn't longer than n bytes?",
#  'Slicing Data Using Criteria in Pandas',
#  'Python client server communication',
#  'Plot cannot opened in python laucher in Mac',
#  'Multiple overlapping plots with independent scaling in Matplotlib',
#  'Creating a dictionary of 700k items in Python?',
#  "Using Selenium's Python API - How do I get the number of rows in a table?",
#  'Code to verify updates from the Google Safe Browsing API',
#  'How can I access this text widget from another function?',
#  'Using lookahead with generators',
#  'retrieve data from post requests in the form of JSON structure',
#  "How to pass variable for dropping table execution in Python's MySQLdb",
#  'Is there any Python function that will format a measurement and an uncertainty parenthetically?',
#  'Adding a value to an Object retrieved via a QuerySet',
#  'How to add email to Stripe custom form for receipts (error: Received unknown parameter: email)',
#  'Get Host Name Without Port in Flask',
#  'Django Named groups not matching',
#  'Opening an external program',
#  'Integer array to string in Python',
#  'How to avoid program freezing when connecting to server',
#  'substring extraction',
#  'PyGTK StatusIcon with transparency',
#  'Shortening line segments in Matplotlib plots',
#  'Efficient Stack implementation in Python',
#  'Browse for file path in python',
#  'Flask redirect to url with multiple slashes',
#  'How to allow submission of empty string in django forms?',
#  'Python - Toggling a connection to my local SOCKS proxy',
#  'Remove background colour from image using Python/PIL',
#  'How to pass a python object to C extension and call its method inside?',
#  'Python requests from google return in hebrew',
#  'How to write Django QuerySet to get UNIX_TIMESTAMP of a DateTimeField?',
#  'How to compare multiple numbers from the output of task and print something in Python?',
#  'How we can draw two series of data in "openpyxl" package of python (line-chart)',
#  'Parallelize this nested for loop in python',
#  'How to return to the beginning of the code after it turns false?',
#  'Uploading a file from python application to appengine',
#  'How to access a value of a many2one field from a form submitted in openerp?',
#  'Python tarfile module overwrites existing files during extraction - how to disable it?',
#  'Passing a member function as a function arg?',
#  'How can I remove everything except a selected tag from a html file with python?',
#  'Python decorator with optional callable argument',
#  'Run Python script with path as argument from total commander',
#  'Python - Picking DataFrame columns from all csv files in directory and merging into one',
#  'SQLAlchemy foreign key filtering, using a different field than the foreign key field',
#  'Binomial distribution in python',
#  'getting aggregates of aggregates in pandas',
#  'How to know the version of installed pylab?',
#  'Plot array content in grid',
#  'Using the tornado RequestHandler is it possible to get POST data without specifying a argument?',
#  "How to store a dictionary in a Django database model's field",
#  'Size of Python Counter',
#  'Plotting a histogram in python',
#  'python fabric with dynamic hosts/servers',
#  'How to lock contents in wxTextCtrl?',
#  'remove tag and contents based on child tag value - python lxml',
#  'Python join a list of strings',
#  'Is it considered bad practice to re-use an iterating variable multiple times in a given script?',
#  'Python - Access object attributes as in a dictionary',
#  'A complex transformation of a data set in pandas',
#  'Optimizing mean in python',
#  'Is it possible to set some columns automatically in sqlalchemy',
#  'Webapp2 request application/octet-stream file upload',
#  'Pass n arguments to a third party function',
#  'How to begin writing a python wrapper around another wrapper?',
#  'Python: Check if one dictionary is a subset of another larger dictionary',
#  'Matplotlib: draw a series of radial lines on PolarAxes',
#  'Can I remove the underscores from the name of a python test function',
#  "Posting a form back with it's default values in the Django TestClient",
#  'GTK+ Startup Notification Icon',
#  'Determine whether two complex numbers are equal',
#  'Get text from a single element of the etree in XML',
#  'Create a function which reads all lines of code from text file and put each line into tuples. -Python 3',
#  'How can I put certain lines of text from a text file into a list with Python?',
#  'using while loop to check errors with inputs in a list',
#  'Applying a function on every row of numpy array',
#  'exclude findAll result set',
#  'How python can help me to make my website?',
#  'Maya/Python: How do I scale multiple selected animation curves each from their own specific pivot point?',
#  'Generating unique slug in Django',
#  'Django File-Transfers Save to New File for Each User',
#  'Google App Engine Python: How to display textarea value in mail',
#  'How to utilize the Instagram API with in Flask framework?',
#  'wxpython GUI running a command-line program',
#  'No output in XML file using XMLITEMEXPORTER',
#  'TortoiseSVN GUI from python',
#  'I want to add a value to an existing XML object/tree in python',
#  'Convert a 3d drillhole trace to cartesian coordinates and plot it with matplotlib',
#  'How do I slice a pandas dataframe based on a condition?',
#  'Output matching keyword from a string in python',
#  'Using Python and win32 how can I open multiple emails simultaneously without sending?',
#  'creating a database table using very large csv in python',
#  'Error using ConvexHull from scipy',
#  'Reading an XML file as is (with indentation) in a variable (using Python)',
#  'Converting pyqt ui files into py files',
#  'Enter inputs only power of 2',
#  "Delete / Insert Data in mmap'ed File",
#  'Boto ec2 creating disk takes a long time to be created - Python',
#  'Downloading Image with no Extension',
#  'Find the number of follower using tweepy',
#  'Importation in Python',
#  'Runtime Crash For A Very Basic Python Program',
#  'Jython - Configuring modules path into a jython script',
#  'Possible to make labels appear when hovering over a point in matplotlib?',
#  'Convert binary files into ascii in Python',
#  'if else for None in Python',
#  'get back nan values after storing in HDFStore',
#  'Remove second character in a string in DataFrame',
#  'How to write JSON requests using django',
#  'Python parse text for latin alphabet',
#  "how to change Qtablewidget's spesific cells backround color in pyqt",
#  'How can i grab some photos with python from website',
#  'How can I add a column from one dataframe to another dataframe?',
#  'Filter columns of only zeros from a Pandas data frame',
#  "Spynner doesn't load html from URL",
#  'Need help decompressing zlib data stored in Aztec barcode (Deutsche Bahn Ticket)',
#  'Python format throws KeyError',
#  'Modify interior of a looping function at runtime',
#  'Convert image to a digital matrix using python',
#  'How can I add attributes to a module at run time?',
#  'ValueError: need more than 1 value to unpack (Python)',
#  'How to get the next token (int, float or string) from a file in Python?',
#  'How to define new variable as float?',
#  'How to read a text file of numbers and turn it into a 40x40 list?',
#  'How to produce the i-th combination/permutation without iterating',
#  'How can I get the full list of running processes on a Mac from a python app',
#  'Python String Parsing Floats',
#  'Calculating month-number in python',
#  'Python Variable Assignment If Variable Exists else None in One Line',
#  'Finding same values in a row of csv in python',
#  'Accessing option data',
#  'A django like unique together in turbogears/sqlalchemy',
#  'Simplest linear model with PyMC',
#  'Python: Compositions of functions of multiple arguments /without/ functools',
#  'XML Parsing with python minidom',
#  'Get only one field from django forms in template',
#  'filter a field in a dropdown lit in django admin',
#  'how to feed suds with an already xml-formated request message',
#  'how to change a function in existing 3rd party library in python',
#  'Is there a functional programming idiom for filtering a list into trues and falses?',
#  'How to get new value from function in Python?',
#  'Edit XML value based on Key',
#  'reading file into numpy array python',
#  'Recursive delete in google app engine',
#  'How do you debug (trace execution) of a pylons web application?',
#  'Read an image with OpenCV and display it with Tkinter',
#  'SUDS rendering a duplicate node and wrapping everything in it',
#  'PyV8 crashes with Flask',
#  'Callback for celery apply_async',
#  'Using an SQL expression to insert data with SQLAlchemy (and MySQL)',
#  'Replace current process with invocation of subprocess?',
#  'Mutual exclusion problems with SQLAlchemy (SQLite3 engine) in a multi process context',
#  'How to throw an error window in Python in Windows',
#  'Found regex patterns prints out memory location',
#  "Django ORM - AppRegistryNotReady: Models aren't loaded yet",
#  'A dictionary of keys and lists as their values. How to identify item in the list, and move to another list? (python)',
#  'Python converting a tuple (of strings) of unknown length into a list of strings',
#  'MySQLdb input where strings contain string delimiters',
#  'Deal with overflow in exp using numpy',
#  'return a FaultObject on purpose from pyamf',
#  'Generator of passwords not working properly',
#  'Find a specific tag with BeautifulSoup',
#  'WTForms creating a custom widget',
#  'django database delete specific number of entries',
#  'How to return a substring after it occurs after another string?',
#  'How to access decoded JSON values in .txt file',
#  'Python - Check if two values(strings) are both in dict',
#  'Regex to get a string in frame',
#  'Writing string entries in a csv to an array in python?',
#  'How can I more easily save value in txt file to variable? python line.split',
#  'How to feed success url with pk from saved model?',
#  "Getting weather conditions using Python - I'm confused by JSON format",
#  'python ISO 8601 date format',
#  'Strip the First Four Rows of a CSV in Python?',
#  'Reading lines in a file',
#  'Pygame blitting only updated sufaces',
#  'Python script to do a GET request on 2 urls in a cron job',
#  'Python - Way to recursively find and replace string in text files',
#  'How to install twitter4j package(java) alternative in python?',
#  'Python multiprocessing Pool on Windows 8.1 spawns only one worker',
#  'Rearrange a Python List',
#  'Determine cluster size of file system in Python',
#  'How to copy a database with mysqldump and mysql in Python?',
#  'Robust regression with empty pandas dataFrame columns',
#  'Trying to send xml file using Python Requests to OpenStreetMap Overpass API',
#  'how to define same variable for two values using python',
#  'Loop backwards using indices in Python?',
#  'Python 3 basic auth with pinnaclesports API',
#  'Iterating variables to change its features in Python',
#  'how to get the original start_url in scrapy (before redirect)',
#  'pythonic way of changing old names by new names',
#  'getting variable',
#  'Comparing a list with file rows',
#  'Python Subprocess returns non-zero exit status only in cron',
#  'How to add variables into a string?',
#  'How do I override delete() on a model and have it still work with related deletes',
#  'Is it possible to debug CherryPy applications?',
#  'Array/Image Interpolation in python',
#  'How can i work around the ValueError from random.sample in Python?',
#  'Alternative to nested for loop',
#  'python conditional access to list of lists',
#  'Python - invalid syntax for loop',
#  'Add values and columns in specific order to Pandas DataFrame',
#  "Python: How to get argument's name runtime",
#  'Set files to ownership of current directory in Python',
#  'Count multiple fields in MongoDB using python',
#  'matplotlib plotting dictionary keys as column labels',
#  'How __hash__ is implemented in Python 3.2?',
#  'How can I make a wxPython app constantly update and execute code?',
#  'Dictionary of a dictionary with duplicate keys',
#  'How can I catch errors from subprocess in a python cgi script?',
#  'Simple cross import in python',
#  'Replacing NaN values with actual values with two pandas DataFrame',
#  'Object attribute in python',
#  'Django: How to pre-populate a form when using non-model data?',
#  'Python assign value X if variable V is 1, Y if it is 43,',
#  'Receiving NaN for a column in pandas DataFrame',
#  'Finding zero values with odeint',
#  'Testing a django post view with curl',
#  'How can I ignore specific files when I am parsing a directory?',
#  'Making an ajax get request with django',
#  'Get backspace in python from stdin?',
#  'Equivalent of alarm(3600) in Python',
#  'Can I save a text file in python without closing it?',
#  'How to read ahead in a file when looping through it with Python?',
#  'Best way to save availability of user over days of week in python/django',
#  'django how to insert into tables reference each other',
#  'Mastermind Game in Python',
#  'Python/Selenium - Chrome Web Driver, Click Action',
#  'How to make a slower timer? (Python)',
#  'From list to sentence on python3',
#  'How to use TermQuery to do an AND query across multiple terms?',
#  'IRC bot make loop sleep without interrup the main loop',
#  'modifying a nested dict while iterating',
#  'How to get gpg-agent to ask for passphrase when generating keys with GPGME?',
#  'String replacement using modulo in Python for raw_input?',
#  'Segmenting letters in a Captcha image',
#  'uploading file using urllib2',
#  'How can I embed two fields together in serializer',
#  'django foreign key relation lookup',
#  'extract from python dictionary',
#  'sympy lambdify RuntimeWarning: invalid value encountered in double_scalars',
#  'Filtering files with python',
#  'Python - Finding next element in list matching a condition. Substitute previous entry',
#  'Finding if a number falls within a certain range python',
#  'Trouble matching regex that includes a dot',
#  'Wxpython textctrl sluggish when using SetStringItem on a loop',
#  'Creating a custom form for mechanize',
#  'UnicodeDecodeError reading string in CSV',
#  'python, list everything between two tags',
#  'PyQt4 scroll glitch',
#  'How to scroll automaticaly within a Tkinter message window',
#  'How to execute a command and put the answer in a dictionary',
#  'How to add method return value to list in python?',
#  'Repeatedly querying xml using python',
#  'Python BeautifulSoup Extracting PHP Links',
#  'tkinter integration with glib mainloop',
#  'Remove all edges between a subset of nodes',
#  "How can I increase each button's size in this python code?",
#  'Python: Need to replace a series of different substrings in HTML template with additional HTML or database results',
#  'pika with celery, connection closed',
#  'Pytest - How to pass an argument to setup_class?',
#  'python: whtat is the right way to remove element from list',
#  'Implementing GObject interfaces in Python',
#  'How to resolve the hardcoding when a newer version of the library i use uses a different function name? - python',
#  'Django Inlineformset with two same foreignkeys',
#  'get all the paths of files inside a directory python',
#  'how to insert jpeg image into excel sheet in unix',
#  'Trying to select data from all columns that start with string from a pandas dataframe',
#  'Scraperwiki - python - skipping a table row',
#  'How to import from a python script that requires command line input',
#  'Python - Searching String In Text File',
#  'Setting sensitivity to specific Gtk3 MenuActions (python)',
#  'how to avoid repeated values retrieved from database?',
#  'Calculating moving average for values in a dictionary with keys in a specific range',
#  'why cant I use a string when concatenating a url for Beautifulsoup?',
#  'Continue in parent for loop',
#  'Peewee: how to select multiple rows where id matches the list?',
#  'Pandas Dataframe or Panel to 3d numpy array',
#  'Extract Data from file using python',
#  'Extracting .app from zip file in Python',
#  'Django Models Create a Coustom Query',
#  'How to combine different integers to one',
#  'wxPython: TreeCtrl: How can I get a tree item by name?',
#  'How to search txt file from python using while loop',
#  'Multiple files AND folder selection in a QFileDialog?',
#  'How to set the application name in spynner/PyQt4?',
#  "Getting HTML to linebreak in django admin's display",
#  'RESTFUL POST with Python request to Glassfish Server',
#  "'Put' in SFTP using PAramiko",
#  'splitting a path with python',
#  'How do I get a Cron like scheduler in Python?',
#  'How to reflect database objects using Pony ORM?',
#  'message box for spin ctrl event in wxpython',
#  'get rid of commas in a list python',
#  'Generating a cache busting key in Plone based on the process start-up timestamp',
#  'Python zip numpy arrays of different dimension',
#  'Splitting the legend in matploblib',
#  'Store Array Locations in Variable',
#  'Plotting 3d data in matplotlib',
#  "Can I use aspects in python without changing a method / function's signature?",
#  'For loop only goes through one iteration in python',
#  'Calculate Euclidean distance for each item in a list',
#  'how to import python variable to bash',
#  'Python Itertools permutations only letters and numbers',
#  'How to make wxPython frame stands long?',
#  'Python appending to two lists when it should only append to one',
#  'Determining if two values are equal, without using comparison operators (==, <=, >=, <, >)',
#  'How to verify POST file transfer with python requests library?',
#  'How can I access a deeply nested dictionary using tuples?',
#  'Aggregate data using the ORM',
#  'python - find index postion in list based of partial string',
#  'Search multiple field form data in mysql database with python',
#  'How can I properly send a command to Maya using os.getcwd() in Python',
#  'Calculate the center of a contour/Area',
#  'Create a list composed of one string per regex substitution?',
#  'Realized Variance in Python',
#  'text color in python-pptx module',
#  'ploting graphe with time format from txt file in python',
#  'Print String in decreasing length',
#  'Importing python file from other directory',
#  'Attempting to calculate total in views - displaying blank in template',
#  'Python selenium find elment by background gradient',
#  'How to open a file to write to, write new information, and then close the file?',
#  'Help with Python while loop behaviour',
#  'Fabric + django asynchronous prompt for sudo password',
#  'How to save a dictionary to a file with key values one per line?',
#  'Fast value swapping in numpy array',
#  'How to get Python interactive console in current namespace?',
#  'Create legend for scatter plot using the label of the samples in matplotlib',
#  'pyCurl WRITEFUNCTION callback with parameters',
#  'How to fill colors in piechart using  Pychart',
#  'MySQL syntax error in python but working in MySQL shell',
#  'Passing Variable from Function in Python',
#  'Python: (sampling with replacement): efficient algorithm to extract the set of DISSIMILAR N-tuples from a set',
#  'Python: Conditional variables based on whether nosetest is running',
#  'Change the value of a dictionary to key of a dictionary in python',
#  'Writing multiple dictionaries to CSV with one header with Python',
#  'How to extract various parts of a string into separate strings',
#  'How to solve my deadlineexceedederror for a GAE cron task?',
#  'How to deal with configuration variables in Python?',
#  'Python - Splitting List That Contains Strings and Integers',
#  'python logging into file as well as wxpython txt ctrl',
#  'LPTHW Excercise 48 Help - Working with Tuples in Lists',
#  'Add slider to matplotlib chart',
#  'Double Iteration in List Comprehension',
#  'Python: How do you get a programme to prompt the user a certian fixed amount of times for a user input?',
#  'Variables has the same value, pygame',
#  'multiple self-contained filters applied during a single iteration',
#  'Finding root/zeros of a function',
#  'Django, can I get reference objects included with a queryset',
#  "pylint can't find QtCore in PyQt4",
#  'PyQt/PySide How to access/move QGraphicsItem after having added it to QGraphicsScene',
#  'Sublime: Change Python version used by plugins',
#  'Is there a Python library than can simulate network traffic from different addresses',
#  'How to add a logger to a module in Python?',
#  'How to perform HTTPS Calls in Pycurl?',
#  'How to bundle files together in a program?',
#  'How to generate random IPv6 address using Python(or in Scapy)?',
#  'kernel32 library via excel com in Python',
#  'Parsing a txt file into a dictionary to write to csv file',
#  'Removing redundant symbols from string',
#  'How do i build a dictionary out of a tuple that holds lists of integers?',
#  'Write a list into Excel',
#  'Convert string in base64 to image and save on filesystem in Python',
#  'Expected a character buffer object',
#  'OpenERP: answering module configuration via XML-RPC',
#  'Python "join" on both sides of strings?',
#  'Python for loop, print same items once',
#  'How can I customize a drop-down list form element in django?',
#  "Python dictionary: sum up numerical and remove 'None' values from nested dictionary and assign results to keys of first level",
#  'Python: how to optimize',
#  'How to match anything (DOTALL) without DOTALL?',
#  'Is it possible to calculate the value of a field from another field in the same form in OpenERP?',
#  'Set a cookie and retrieve it with Python and WSGI',
#  'Python, HTTPS GET with basic authentication',
#  'Reading a binary .dat file as an array',
#  'Preventing polls without choices from being published',
#  'Python - Plot one column of data from multiple text files into single graph',
#  'How to plot 500 pairs of successive random numbers in python?',
#  'Assigning a RGB column array to an arbitrary number of columns in an image array',
#  'How to Resize and Position Buttons in PySide?',
#  'Mayavi, python axes INDICATOR',
#  'Python - how to properly extend classes to modify the operation of base methods',
#  'Plotting curved line in Python Basemap',
#  'Run python behave from python instead of command line',
#  'Python Pandas: Get row by median value',
#  'sqrt for element-wise sparse matrix',
#  'Using SST framework, how do you click a link by css class or xpath?',
#  'how to plot time series where x-axis is datetime.time object in matplotlib?',
#  "'else' statement in list comprehensions",
#  'calculating graph weight in python with NetworkX',
#  'Replace elements in a matrix (Need help to make this faster)',
#  'How to use try Exception block to save my code from abnormal termination?',
#  'Can Selenium web driver have access to javascript global variables?',
#  'Filtering on foreign keys',
#  'PyQt - Implement a QAbstractTableModel for display in QTableView',
#  'Finding mismatched item for same index in a python list',
#  'How to judge all the subprocess over in gevent?',
#  'Basic python: how to increase value of item in list',
#  'Finding row wise average and average of all rows of space delimited file',
#  'How can I unserialize a numpy array that was cast to a bytestring?',
#  'How to remove repeating non-adjacent string',
#  'Python: Efficient creation of binary image from line',
#  'Is there a way to run a saved SQL query from Python (using cx_Oracle)?',
#  'How Can I Allow Object Editing in the Django Admin For Specific Objects ONLY?',
#  'Removing ListItemButtons from kivy adapter widget',
#  'Django Datetime Query',
#  'How to remove all html tags from downloaded page',
#  'Migrating from App Engine Files API',
#  'Stomp.py return message from listener',
#  'is there COMMIT analog in python for writing into a file?',
#  'Getting specific numbers from a text file containing a mix of alphanumeric characters in python',
#  'Python error log pattern matching',
#  'python pandas: how to group by and count with a condition for every value in a column?',
#  'Converting timestamp with milliseconds to datetime in python',
#  'Python - Generator case where nothing to return',
#  'How to get the text of cluster centers from scikit-learn KMeans?',
#  'Generate functions without closures in python',
#  'Are There any Tkinter Widgets like OptionMenu That Can be Nested?',
#  'Sending hexadecimal or ASCII value stored in a variable using pyserial',
#  "I'm making a python function to check if input is a date",
#  'How to exit all the joined processes in case any one has an exception - Python',
#  'how to select inverse of indexes of a numpy array',
#  'Difficulty with using Lists to search in xlrd',
#  'Replace two nested loops with a dictionary comprehension',
#  "How to call another Object's Method from the current Object's Method in Python",
#  'How to convert raw images into png using python',
#  'list of import statements in python',
#  'Replace sequence in list with a value in Python',
#  'str assignment in a matrix in python',
#  'undistortPoints in OpenCV (cv2) with Python wrong results',
#  'Python to extract specific numbers from text file',
#  'Insert characters in a string using python',
#  'Retrieve UNIX TIMESTAMP in django api call',
#  'Python ConfigParser Section Key Value',
#  'Search a list in a list',
#  'Converting string to number in python',
#  'Django admin - make all fields readonly',
#  'How do I ignore certain tags in lxml before parsing it?',
#  'python saving output from a for iteration and subprocess for checksum',
#  'Trying to negate the end of the string',
#  'in python, I want to select from array an range by given string',
#  'How to add latex figure captions below jupyter / matplotlib figures',
#  'Parse events from an .ics file in Python',
#  'How to make Python script executed in background?',
#  'nested if else statements in python',
#  'Show python object name',
#  'Python: Pandas Dataframe how to multiply entire column with a scalar',
#  'Make a twister server take initiative',
#  'django model translation - filter by translated field',
#  'How to use parse.com Session Token with ParsePy?',
#  'uWSGI, gevent, a few redis calls and how to timeout a post if greater than 90 ms',
#  'igraph set edge width by EID python',
#  'Remove element in a list with condition',
#  'Using pandas to read downloaded html file',
#  'python syntax for formatting integer',
#  'How to dynamically access class properties in Python?',
#  'How can I make a function that prints a histogram based on the indexes of a list (more detalis inside)?',
#  'Making a collatz program automate the boring stuff',
#  'Python: How to find duplicate folder names and rename them?',
#  'How do I create a Python set with only one element?',
#  'Parsing a simple text file in python',
#  'Adding tags to mongodb records from flask application',
#  "How to escape char in Python 3 ''' string?",
#  'Maximum and Minimum Value of a Dictonary Using Python',
#  'How to turn off blinking cursor in command window?',
#  'Plot ConvexHull in basemap',
#  'Replace slice of a numpy array with values from another array',
#  '"Flattening" a list of dictionaries',
#  'wrong indentation of multi-line python statement in emacs',
#  'Applying a value offset through a list in a way that resembles a sine wave (eases in and out)',
#  'Getting HTTP GET arguments in Python',
#  'How to get the matching element of a set in Python 3?',
#  'How should I deal with a circular import in Google App Engine?',
#  'How do I decrease the memory used by a large list in python',
#  'How to detect mouse and keyboard inactivity in linux',
#  'Python regex help, match anything before meet a letter',
#  'How to connect two state circles with an arrow in tkinter?',
#  'GROUP BY single column without doing raw sql',
#  "TypeError: unhashable type: 'list', Remove duplicate items in a list",
#  'how to parse and get result from JSON in python',
#  'numpy matrix to shared array for multiprocessing',
#  'How to construct a list of grouped item based on another list in python?',
#  'Building the pHash library on Windows',
#  'capturing states between tags in python using xpath',
#  'URLFetch behind a Proxy Server on App Engine Production',
#  'Remember path over session in QFileDialog',
#  'How to get chars that are actually displayed in wx.TextCtrl?',
#  'Overlaying a scatter plot on background image and changing axes ranges',
#  'Python 2.7 - Extract Zip From Email Message File',
#  'Python - ObjectListView Filter',
#  'Scrambling of letters within a text file',
#  'loops with multiple variables',
#  'how to speed up my couchdb views written with python',
#  'Ignoring items that have fewer than three words',
#  'Matching multiple <p> tags in scrapy',
#  'Cleaning Column Data Where Data Has Repeated Itself (Python)',
#  'Casting a bytearray instance in ctypes',
#  'Trying to Figure out how to properly use a while loop in Python 3.3.0',
#  'How to parse a loosely structured document',
#  'Update an online JSON file',
#  'Python on Windows: Run multiple programs sequentially in one command prompt',
#  'How to make "int" parse blank strings?',
#  'Python IN operator for List comparision',
#  'JSON Schema: validate a number-or-null value',
#  'How do I re.search or re.match on a whole file without reading it all into memory?',
#  'Value prints correctly in function, but when returned is None',
#  'Kernel density estimation of the histogram of an image',
#  'Setting Histogram Bar Widths in Subplots as Equal',
#  'Add a list to an already stored document in pymongo',
#  'How can I loop over a tuple with two tuple elements and print a nice formatted string result of multiplying the tuple elements?',
#  'Storing RSS pubDate in App Engine Datastore',
#  'python pycurl get final url redirect',
#  'How to send json from django view and receive it on HTML',
#  'Pandas DataFrame including three numpy arrays',
#  'How to make syncdb work automatically in Django?',
#  'How to wait till a directory exist in Python (Ubuntu)',
#  'String variables in python function?',
#  "Matching user's input with query from sqlite3 db in python",
#  'public string blaBla { get; set; } in python',
#  'wxPython, creating bit map',
#  'How to use a Sqlalchemy Model out of a session context?',
#  'How to "nicely" print out a tree without node information',
#  'Is there a way to do cumulative np.bitwise_or in pandas groups?',
#  'How to find min/max values from rows and columns in Python?',
#  'How to read a line a few lines down while looping in Python?',
#  'My data is being printed all on one line while writing into a CSV file',
#  'Django - Validating if user has created an object',
#  'Create a load of button images from .jpg files',
#  'C TCP Echo Server - Data displays only on close()',
#  'Python: Resetting a variable',
#  'No space benefit using sparse Pandas dataframe despite extremely low density',
#  'python numpy/scipy find count or frequency of a relative variable in multi-dimensional array',
#  'How do you sort files numerically?',
#  'Scraping with selenium 4',
#  'How to send an integer over a socket to a Java application using python?',
#  'python docx align both left and right on same line',
#  'How to return the number in socket.inet_aton?',
#  'Creating Menu in Python',
#  'Executing a command and storing its output in a variable',
#  'Psychopy: bad contrast in blendMode add',
#  'mechanize opening multiple pages',
#  'How to script SOAP based web service using SUDS python package',
#  'How do I programmatically check whether a GIF image is animated?',
#  'How can I use \\r to make Python print on the same line?',
#  'PyQt4 QSqlTableModel, QTableView intermittent update',
#  'How to log redirects in Pyramid?',
#  'Halving each continuous number looping',
#  'How to import python files within two subdirectories',
#  'Using IFNULL in sqlalchemy core',
#  'How to click a button by twill?',
#  'pandas, matplotlib: a way to assign same colors, line styles for same column labels across subplots?',
#  'How to activate/deactivate a virtualenv from python code?',
#  'Pandas to_csv with escape characters and other junk causing return to next line',
#  'making a sequentie complementair',
#  'Grid within a frame?',
#  'Python and pushbullet api: send a file',
#  'How can I get Python to use upper case letters to print hex values?',
#  'Passing array of strings as parameter in python ctypes',
#  'Print shape in Python',
#  'Get list from pandas DataFrame column headers',
#  "Making python import statements 'insensitive' to working dir of launching script",
#  'project euler question7 in python',
#  'How to add legend to imshow() in matplotlib',
#  'How to create a pandas dataframe containing columns with special characters?',
#  'Tuple in Couchdbkit',
#  'How to print the value entered in entry widget into canvas',
#  'Python string manipulation without comparison',
#  'How to prevent PyMySQL from escaping identifier names?',
#  'python change string between certain two words',
#  'Resize multiple items inside of a WxPython BoxSizer evenly?',
#  'Writing image to file in python from website',
#  'How to make a non-square contourf-plot',
#  'Using os.walk to add to list',
#  'Fitting a gaussian to a curve in Python',
#  'Build a dictionary from successful regex matches in python',
#  'Passing objects from python to powershell',
#  'peewee: Get a single model instead of SelectQuery when back-referencing a foreign key',
#  'Python script that prints its source',
#  'Using python to analyse coin tossing statistics',
#  'Python, MySQL Deletiong of row not working',
#  'How to log python program activity in Mac OS X',
#  'How to custom handle iteration in python dictionary?',
#  'Printing grid values from lists in a list',
#  'Rounding a number while using string formatting in python',
#  'Capturing a single image from my webcam in Java or Python',
#  'Unable to unpack elements in list',
#  'Numpy -- Split 2D array into sub-arrays based on indices',
#  'Reshape an array in NumPy',
#  'compare 3 lists and delete all matched elements',
#  'Change field name in django admin',
#  'Check for specific sequences in list',
#  'Exectue function every one hour in Python',
#  'Create a new variable as named from input in Python?',
#  'Modify a large list without any loops in python',
#  'Changing canvas size dynamically',
#  'Extra space around a matshow/imshow plot after scaling',
#  'Mapping dummy variables in pandas data frame',
#  'TensorFlow - get execution ordering of fetches',
#  'How to detect curses ALT + key combinations in python',
#  'How to get a stereo wav file of the average and maximum volume for each channel? Get the volume in an array on a per second, for example?',
#  'How to check wxPython release from python GUI (IDLE)?',
#  'python soappy add header',
#  'Multiple levels dictionary python',
#  'how to get the value of the widget select?',
#  'Parse out key:values in dictionary nested in MRSS feed using Python Feedparser',
#  'Transform invalid nested json to valid one and change to list',
#  'How to write a Python robot that browses',
#  'Python IO: Reading a file using format specifier',
#  'How do I find out the Python, Django versions and path that a Django site is running?',
#  'Change cell values in numpy 2D array to match a number',
#  'Parsing file via Python',
#  'PyOdbc fails to connect to a sql server instance',
#  'Python - output from functions?',
#  'Import numpy with python 2.6',
#  'Casting from list of lists of strings to list of lists of ints in python',
#  'Python MatplotLib plot x-axis with first x-axis value labeled as 1 (instead of 0)',
#  'How can i use Scrapy in conjunction with Mysql?',
#  'Downloading Protein Sequences of multiple Organisms',
#  'Create a tree data using networkx in python',
#  'modify list element with list comprehension in python',
#  'Create 3D Grid from opposite vector coordinates',
#  'Plotting surface without axes',
#  'pylinter config for sublime text 3',
#  'Calculate Discrete Cosine Transformation of Image with OpenCV',
#  'Boto3 - Disable automatic multipart upload',
#  'Python: Want to use a string as a slice specifier',
#  'Parsing JSON from a URL in Python 2.6',
#  'How can i add extra data in object list in django python',
#  'Count elements in a box',
#  'PyQt + QtWebkit behind a proxy',
#  'Create only ONE table with Flask + SqlAlchemy',
#  'Extracting substring from URL using regex',
#  'How do I find the angle between 2 points in pygame?',
#  'How would I call 32bit exes in Windows 64bit with python?',
#  'How to update value and combine columns in csv file using Python',
#  'Python method parameter list',
#  'How to bind a name with multiple objects or values in python',
#  'Queue datastruct -- find first element in queue that has not previously been queued',
#  'How to run GUI2Exe from command line?',
#  'open shelve file',
#  'Python - Adding new variables automatically',
#  'How to set the axis tick to be only major on python',
#  'Please explain Python for loops to a C++/C#/Java programmer',
#  "Python Linkedin, How to share content on user's wall",
#  'String Pattern on a bytes-like object',
#  'django - filtering url responses',
#  'how would i design a db to contain a set of url regexes (python) that could be matched against an incoming url',
#  'How can I make this Project Euler solution execute in Python at the same speed as Java?',
#  'Fastest way to pack and unpack binary data into list',
#  'Why when I make a ping test from python does it have a different response to in windows cmd?',
#  'Unpacking an unspecified amount of variables',
#  'Python syntax for namedtuple',
#  'Using range to display numbers in a interval',
#  'Know any creative ways to interface Python with Tcl?',
#  'How can I create Django ModelForm for an abstract Model?',
#  'How to use variables as list indices?',
#  'Extracting a particular type of string from a text file using nltk',
#  'Python baseline correction library',
#  'simple dictionary for getting value',
#  'Pretty Print Formatting Issue in Python',
#  'Copy from a file until a certain marker string is found',
#  'How to update/add data to Django application without deleting data',
#  'how to store registration value in to database?',
#  'How to install a missing python package from inside the script that needs it?',
#  'Correct approach for calling a function regardless of parameter type',
#  'How to right align level field in Python logging.Formatter',
#  'convert rgba color codes 255,255,255,255 to kivy color codes in 1,1,1,1',
#  'print binary tree level by level in python',
#  'Python: Parallel processing of N files in list',
#  'How to make web2py dev server track file changes and restart automatically?',
#  'Issue system call from Python, get filename for output',
#  'Validate an argument over another',
#  'python: recursive check to determine whether string is a palindrome',
#  'How do you put data from a txt file into a Grid?',
#  "After Minimize to Tray Application Doesn't Close Properly",
#  'How can i know if a contour is open or closed in opencv?',
#  'Iterating and printing JSON objects in Python',
#  "How can I use pywin32 with a virtualenv without having to include the host environment's site-packages folder?",
#  'Disabling Cookies in Webdriver for Chrome/Firefox',
#  'Converting a string to dictionary in python',
#  'Printing main window in PyQt',
#  'how to draw line chart with date fomat on excel using openpyxl of python',
#  'Is a, b = b, a + b good python?',
#  'How to use tuples as parameters for __getitem__()?',
#  'Retrieve feed from a specific category with appengine python youtube api',
#  'python list of dictionaries sort multiple keys',
#  'How can I convert this string to list of lists?',
#  'Please suggest how to write a text from webpage text box to clipboard',
#  'How to replace a particular comma in a CSV file using Python?',
#  'How to immediately execute AsyncHTTPClient() without server (using interactive interpreter)',
#  '3n+1 Programming Challenge in Python',
#  'Efficiently constructing sparse biadjacency matrix in Numpy',
#  'Change/Overlay color on single-colored PNG image with transparent background?',
#  'Rotate x tick labels using subplots',
#  'Numpy Image Arrays: How to efficiently switch from RGB to Hex',
#  'Force import module from Python standard library instead of PYTHONPATH default',
#  'Copy N lines from File1 to File2, then delete copied lines in File1',
#  'Dropping an external file into a QTreeWidget',
#  'How to limit execution time of a function call in Python',
#  'random generation of unique combination from two column',
#  'Using matplotlib to graph rows by column of a csv file',
#  'Launch an independent process with python',
#  "How to generate a fully connected subgraph from node list using python's networkx module",
#  'Scikit-learn cross validation scoring for regression',
#  'Filtering in Django',
#  'Pandas Dataframe Add a value to a new Column based on the previous row limited to the maximum value in that column',
#  'How to catch str exception?',
#  'Python reading specific csv column into list',
#  'How do I increase the dimensions of a numpy int32 array?',
#  "can I return data in python twisted's dataRecieved method",
#  'Creating a generator expression from a list in python',
#  'Python: how to convert from Windows 1251 to Unicode?',
#  'Dynamically exclude or include a field in Django REST framework serializer',
#  'Open a program with python minimized or hidden',
#  'How to transform items using sklearn Pipeline?',
#  'Convert datetime to unix timestamp in python',
#  'remove duplicates from nested dictionaries in list',
#  'Logging into website with requests',
#  'Fast way for multiple processes to read from central source in Python?',
#  'List in the form of a string into a real list',
#  'Casting an int to a string in Python',
#  'create file of particular size in python',
#  'pandas - add column based on conditions',
#  'How to make a QInputDialog trigger the virtual keyboard to show up?',
#  "Overriding __setitem__ in Python dict subclass doesn't work for setting values of items inside",
#  'How to deserialize the datetime in a json object in python?',
#  'Interleaving multiple iterables randomly while preserving their order in python',
#  'Sort numpy string array with negative numbers?',
#  'PanedWindow in module Tix',
#  'Networkx creating a graph with node attributes to determine which edges are connected',
#  'Python dictionary value assignment from variable',
#  'How can I draw a bitmap rotated in wxPython?',
#  'SQL Date Variables in Python',
#  'Run a python function every second',
#  'Understanding a factorial function in python',
#  'sending emails with python - subject of message missing',
#  'trying to make a checkbox cause a redirect using javascript',
#  'Train two models concurrently',
#  'appending to a list using basic for vs list comprehension',
#  'in-memory database in Python',
#  'Multi-database in Django',
#  'How to list all types (running, zombie, etc.) of processes currently in linux with native python library',
#  'open a terminal from python',
#  'get current directory - Python',
#  'Build sqlalchemy query from string',
#  'How to reverse key value pair in list with dictionary as value?',
#  'Pickle incompatability of numpy arrays between Python 2 and 3',
#  'I need to call a function until it returns 0 in python',
#  'How to create pair RDD with elements that share keys in source RDD?',
#  'Convert shift_jis to utf-8',
#  "How to find when a string's letter matches a another's letter?",
#  'How to send raw XML in Python?',
#  'Matching multiple regex groups and removing them',
#  'Web interface for a twisted application',
#  'recursing a dictionary of lists of dictionaries, etc et al (python)',
#  'how to make django comment model field Site not required',
#  'How to write a function that outputs a two-column table',
#  'Un-pivoting/Stacking a pivot table with Python Pandas',
#  'Sanitizing a file path in python',
#  'JSON consumption in python django',
#  'Python selenium click on button link',
#  'How to save big array so that it will take less memory in python?',
#  'How can I resize the main window depending on screen resolution using PyQt',
#  'How to create a ModelResource for a Model that inherits another Model using django-tastypie?',
#  'Writing Regular Expressions to a file Python',
#  'Django models -Best way to store multiple contact numbers',
#  'I need a Python Function that will output a random string of 4 different characters when given the desired probabilites of the characters',
#  'Items ordering in Python dictionary',
#  'Django get data by one table with filtered set of related objects',
#  'pygtk - dynamically update the widgets taking input from the gtk combo box',
#  'Pythonic way to set sort order?',
#  'check carriage return is there in a given string',
#  'remove every nth word from file',
#  'Comparing string in Python: String X is ASCII, and String Y is UTF',
#  'Group by max or min in a numpy array',
#  'Selecting rows from a NumPy ndarray',
#  'Efficient saving of an index of docs where a word of a vocabulary occurs',
#  'In python __init__ dictionary arguments defaulting to previous class values',
#  'Click jquery menu item using selenium webdriver',
#  'List Comprehension Over Pandas Dataframe Rows',
#  'Draw a rectangle with two points in wxpython',
#  'How to implement basic auth in Django',
#  'Calling tkFileDialog without opening a parent window',
#  "Tkinter Checkbutton doesn't change my variable",
#  'Joining items in two lists to a string expression',
#  'bpython in Emacs',
#  'How to input a list of tuples',
#  'How to update the legend from matplotlib toolbar',
#  'How to write binary data in stdout in python 3?',
#  'Gtk3 Image full window image from file (python3)',
#  'Python Hashing with lists',
#  'how do i write a text file to csv in python with consideration to columns',
#  'How to get list of IP addresses?',
#  'Python pairSum function with Dictionaries',
#  'Twisted: how to get error parameters from failure?',
#  'Populating a dict from a for loop in Python',
#  'Generate a list of strings with a sliding window using itertools, yield, and iter() in Python 2.7.1?',
#  'Python network convert byte',
#  'Python: Making a beep noise',
#  'How to concatenate string cell contents',
#  'python: proper usage of global variable',
#  'Multiple browsers in Selenium with Python',
#  'How do I access the command history from IDLE?',
#  "django urls that aren't defined",
#  'Python SQLite3 Mac Address with colons lookup',
#  'How do I format a print statement to print to a certain number of decimal points?',
#  'Python how to create a dict of dict of list with defaultdict',
#  'Python Pandas - Re-ordering columns in a dataframe based on column name',
#  'python socket send immediately',
#  'Test if an attribute is present in a tag in BeautifulSoup',
#  'Importing a module which imports from same directory',
#  'Scraping links from more than one URL',
#  "How do I show updated values in the 'label' widget in Python Tkinter GUI?",
#  'How to count only the words that I want?',
#  'A simple Python extension in C',
#  'How to trigger authenticated Jenkins job using standard Python library',
#  'Efficiently checking if number is in range of 2nd number +-10%?',
#  'Unpack list of strings inside another list of strings',
#  'Move radial tick labels on a polar plot in matplotlib',
#  'Pass statement in an if statement',
#  'How can I subtract a day from a Python date?',
#  'Control Font in tkMessageBox',
#  'Writing a dictionary to a CSV file via DictWriter (Python)',
#  'How to use initialize FormModel with request.post and model instance.',
#  'How to create table/matrix using user input?',
#  'Python Deeply Nested Dictionary of a Specific Type',
#  'PyQT - setting the text color for a QTabWidget',
#  'How to convert -0.00 to 0.00 in Python 3',
#  'How to find multiplicity of prime factors in order to get number of divisors',
#  'reportlab - cannot set top margin to zero in physically printed page',
#  'Python: count frequency of words in a txt file',
#  'How to create a dynamically updating list of class instances, satisfying a particular condition? (Python)',
#  'python BaseHTTPServer file upload with maxfile-size',
#  'Pythonic Approach to Multiple Parent Method Calls',
#  'Flask app hangs while processing the request',
#  'Using python scrapy to extract links from a webpage',
#  'How to compare two lists in python',
#  ...)

# %%
word_list = []
regex = re.compile('[%s0-9]' % re.escape(string.punctuation))
for comment in comments:
    l = regex.sub('', comment).split()
    l = [w.lower() for w in l]
    word_list.extend(l)
c = Counter(word_list)

# %%
import string
from collections import Counter
import re
import pickle

def comment2list(comment, regex=re.compile('[%s0-9]' % re.escape(string.punctuation))):
    return [w.lower() for w in regex.sub('', comment).split()]


    def build_vocab(file_name='data/train.pkl', vocab_length=2000):
    # load data
    with open(file_name, 'rb') as f:
        data = pickle.load(f)

    # comments only
    comments, _ = zip(*data)

    # traverse
    word_list = []
    for comment in comments:
        word_list.extend(comment2list(comment))
    c = Counter(word_list)
    most_common_words, most_common_words_count = zip(*c.most_common(3000))
    print('5 most common words:', most_common_words[:5])
    print('5 most common words count', most_common_words_count[:5])
    comment_dict = dict(zip(most_common_words, range(len(most_common_words))))

    # add additional annotations
    for token in ['<EOS>', '<SOS>', '<UNK>']:
        assert(token not in comment_dict)
        assert(max(comment_dict.values()) < len(comment_dict))
        comment_dict[token] = len(comment_dict)

    with open('dicts/comment_dict.pkl', 'wb') as pfile:
        pickle.dump(comment_dict, pfile)


class Encoder():
    def __init__(self):
        with open('dicts/comment_dict.pkl', 'rb') as f:
            self.vocab_dict = pickle.load(f)

        self.invert_dict = self.__invert(self.vocab_dict)

    def __invert(self, d):
        return dict([(y,x) for x, y in d.items()])

    def encode(self, comment): 
        comment_list = ['<SOS>']
        comment_list.extend(comment2list(comment))
        comment_list.append('<EOS>')
        comment_list = [w if w in self.vocab_dict else '<UNK>' for w in comment_list]
        return [self.vocab_dict[w] for w in comment_list]

    def decode(self, seq):
        # to sentence
        return ' '.join([self.invert_dict[index] for index in seq])

# %%
print('--- build vocab..')
build_vocab()

with open('data/train.pkl', 'rb') as f:
    data = pickle.load(f)
# Select one datus as exmaple
comment, _ = data[7755]
encoder = Encoder()
print('-------- Original comment --------')
print(comment, end='\n\n')

print('-------- encoded comment --------')
print(encoder.encode(comment), end='\n\n')

print('-------- decoded comment --------')
print(encoder.decode(encoder.encode(comment)))
# Out:
# --- build vocab..
# 5 most common words: ('a', 'python', 'in', 'to', 'how')
# 5 most common words count (9846, 9328, 9102, 9003, 6158)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-b355373480a2> in <module>
#       6 # Select one datus as exmaple
#       7 comment, _ = data[7755]
# ----> 8 encoder = Encoder()
#       9 print('-------- Original comment --------')
#      10 print(comment, end='\n\n')
#
# <ipython-input-43-e759afa5f4a4> in __init__(self)
#      38 class Encoder():
#      39     def __init__(self):
# ---> 40         with open('comment_dict.pkl', 'rb') as f:
#      41             self.vocab_dict = pickle.load(f)
#      42
#
# FileNotFoundError: [Errno 2] No such file or directory: 'comment_dict.pkl'
